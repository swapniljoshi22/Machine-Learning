# %%
# pandas tutorial

# %%
#Python program to interchange first and last elements in a list

# %%
lst=[1,2,3,4,5]

# %%
first=lst[0]

# %%
last=lst[-1]

# %%
lst[0]= last

# %%
lst[-1]= first

# %%
lst
# Out:
# [5, 2, 3, 4, 1]

# %%
def interchange(lst):
    first=lst[0]
    last=lst[-1]
    lst[0]= last
    lst[-1]= first
    return lst

# %%
x=[1,2,3,5,6]

# %%
interchange(x)
# Out:
# [6, 2, 3, 5, 1]

# %%
import pandas as pd
import numpy as np
#import tiktoken
import openai
import json
import gc
import os
from langchain.chat_models import AzureChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.llms import OpenAI
from langchain.schema import HumanMessage
from langchain.chat_models import ChatOpenAI
from langchain.prompts import HumanMessagePromptTemplate
from langchain.schema.messages import SystemMessage
from langchain.prompts import ChatPromptTemplate
from typing import Any, Dict
from langchain.output_parsers import PandasDataFrameOutputParser
import pandas as pd
from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain.output_parsers import OutputFixingParser
from langchain.schema import OutputParserException

#df = pd.read_excel(r"C:\Users\sreosha.mallick\Downloads\DOW_RES\File_level_responses\Template\OCR_Payments_all.xlsx")
filenames = df['filename'].unique()
question = {"1.How will Consumer Price Index (CPI) be reviewed under the Consumer Price Index Clause?":"Answer", 
            "2.When will CPI be reviewed under the Consumer Price Index Clause?":"Answer",
            "3.How are adjustments made for CPI under the Consumer Price Index Clause?":"Answer",
            "4.Is there any inflation rate or formula or increase/decraese rate of Consumer Price Index mentioned under the Consumer Price Index Clause?":"Answer",
            "5.What is the cost of living adjustment (COLA) under the Cost of Living adjustment Clause?":"Answer",
            "6.What are the contract terms based on changes in the cost of living under the Cost of Living adjustment Clause?":"Answer",
            "7.What is the payment frequency? Return the response in one word only if mentioned explicitly.":"Answer",
            "8.What is payment trigger event under the Payment Trigger clause ?":"Answer",
            "9.Which party will make the payment to other party under the Payment Frequency clause ?":"Answer",
            "10.How Consumer Price Index (CPI) is contributing to the Cost of Living Adjustment (COLA) under the Cost of Living adjustment Clause?":"Answer",
            "11.What is the change in contract term based on CPI under the Cost of Living adjustment?":"Answer"
            }  


class MetaDataExtractor(BaseModel):
    Q1 : str = Field(description="Find Consumer Price Index and check how it will review.")
    Q2 : str = Field(description="Find Consumer Price Index and check when it will review.")
    Q3 : str = Field(description="Find Consumer Price Index and check how its adjustment.")
    Q4 : str = Field(description="Find Consumer Price Index and check the inflation or wages information.")
    Q5 : str = Field(description="Find cost of living adjustment information.")
    Q6 : str =  Field(description="Find cost of living adjustment information and its contract term impacts.")
    Q7 : str =  Field(description="Find  payment frequency information.")
    Q8 : str =  Field(description="Find payment trigger information.")
    Q9 : str =  Field(description="Find  payment frequency information and the parties.")
    Q10 : str =  Field(description="Find Cost of living dependency on Cosumer Price Index")
    Q11 : str =  Field(description="Find Cost of living dependency on Cosumer Price Index")

parser = PydanticOutputParser(pydantic_object=MetaDataExtractor)
prompt = ChatPromptTemplate.from_template("""You are a Legal expert who knows about legal contracts very well. Determine the answer by copying the entities same as that in the legal text {text} without altering in the place of "Answer"  if and only if the answer is present in the text, don't take answer from historical data.Strictly admire the format and return answers in same format everytime.
                            Question and Answer: \n{format_instructions}\n{question}""",
                            partial_variables={
        "format_instructions": parser.get_format_instructions()})
# prompt = ChatPromptTemplate(
#     messages=[
#         HumanMessagePromptTemplate.from_template(
#             """You are a Legal expert who knows about legal contracts very well. Determine the answer by copying the entities same as that in the legal text {text} without altering in the place of "Answer"  if and only if the answer is present in the text, don't take answer from historical data.Strictly admire the format and return answers in same format everytime.
#                             Question and Answer: \n{question}"""
#         )
#     ],
#     # input_variables=["text","question"],
    # partial_variables={
    #     "format_instructions": parser.get_format_instructions(),
    # },
# )
model = AzureChatOpenAI(
    openai_api_type="azure",
    openai_api_key="24f961442279465daf5f85980cfb3ae8",
    openai_api_base="https://oai-gpt4.openai.azure.com/",
    model_name='gpt-4-32k',
    deployment_name = 'gpt-4-32k-model',
    openai_api_version="2023-05-15",
    temperature = 0,
    model_kwargs = {"seed" : 42, "top_p" : 0})

llm_chain = LLMChain(prompt=prompt, llm=model) #, output_parser=parser
#df = pd.read_excel(r"C:\Users\sreosha.mallick\Downloads\DOW_RES\File_level_responses\Template\OCR_Payments_all.xlsx")
filenames = df['filename'].unique()
text = """ACID PURCHASE AGREEMENT BETWEEN CHEMTRADE REFINERY SOLUTIONS LP AND DOW CORNING CORPORATION CHEMTRADE REFINERY SOLUTIONS LIMITED PARTNERSHIP, having a business address of 1400 Otter Creek Road, Oregon, OH (hereinafter referred to as Seller\"), agrees to supply products and services herein described and DOW CORNING CORPORATION, having its principal place of business at 2200 West Salzburg Road, Midland, MI 48686 (hereinafter referred to as Buyer), agrees to purchase products and services according to the terms and conditions described hereinafter.RECITALS Buyer desires to avail itself of the products and processing services of Seller upon the terms and conditions set forth herein. DEFINITIONS When used in this ACID PURCHASE AGREEMENT (Agreement) the following definitions shall apply: a) Buyer's Plants means Buyers manufacturing site having a business address at 3901 S. Saginaw Road, Midland, Ml 48640 and Buyers manufacturing site having a business address at 4770 Highway 42 E. Carrollton, KY 41008 and Buyer's Plant shall mean either of them, as applicable; b) Dispute means any dispute, claim or controversy arising out of or relating in any way to this Agreement; c) Effective Date shall mean October 1, 2016; d) Fresh Acid means commercial grade sulphuric acid (H2SOx), of 93% strength in respect of Midland, MI and 96% strength in respect of Carrollton, KY, which meets the specifications set out in Exhibit \"A\"; e) \"Party\" means either Buyer or Seller, as the context requires, and \"Parties\" means Buyer and Seller collectively;f) Product(s) shall mean Fresh Acid or Spent Acid, as applicable; g) Seller's Plant means primarily Seller's sulphuric acid manufacturing facilities located in Oregon, OH; but will also refer to other facilities, as may be required to fulfill the requirements of this contract; h) Spent Acid means sulphuric acid (H2SOs4), after it has been used by Buyer in its manufacturing processes, which meets the specifications set out in Exhibit B; Carrollton, KY Spent Acid BP-502, Midland, Mi BP-503 and Midland, MI BP-711\"; i) Ton or Net Ton means a quantity of acid which weighs 2,000 pounds avoirdupois (on a 100% H2S04 basis); NOW, THEREFORE, in consideration of the mutual promises, covenants and agreements hereinafter set forth, the Parties hereby agree as follows: 1. TERM 1.1 The initial period of this Agreement shall begin on October 1, 2016 (the \"Effective Date) and end on September 30, 2019 (such period, the Initial Term). After theInitial Term, this Agreement shall renew for additional one (1) year terms (the Initial Term together with any renewal term(s), the Term), unless terminated by either Party upon written notice given to the other Party at least twelve months prior to the expiration of the Initial Term or any one (1) year renewal term. This Agreement sh
ialmaterial intended to be disclosed, the purpose of the disclosure and to whom the information is being produced. 15.2 For purposes of this Section 15, a specific item of Proprietary Information shall not be deemed to be within the foregoing exceptions merely because it is embraced by more general information in the public domain or in the possession of the Receiving Party. In addition, any combination of features shall not be deemed to be within the foregoing exceptions merely because individual features are in the public domain or in the possession of the Receiving Party, but only if the combination itself and its principle of operation are in the public domain or in the possession of the Receiving Party.15.3 Receiving Party expressly agrees to receive process, use, transfer, or otherwise handle any data from Disclosing Party containing personal data solely to the limited extent necessary to meet its obligations under this Agreement in a confidential manner and in accordance with applicable law. Receiving Party warrants that its employees, representatives, agents, subcontractors act in accordance with this Agreement. Upon reasonable request by Disclosing Party, Receiving Party shall provide proof, satisfactory to Buyer of compliance with this section. In the event that Receiving Party becomes aware of a security breach involving personal data received, processed, used, or otherwise related to this Agreement; Receiving Party will promptly notify Disclosing Party of such breach in writing and cooperate in good faith with Disclosing Party in any related investigation, notification process, or commercially reasonable action requested by Disclosing Party. For purposes of this Agreement, personal data includes facts and opinions relating to an individual whose identity is apparent or can reasonably be determined from the information or opinion in addition to relevant definitions provided by applicable law. For the purposes of this section, security breach includes: (a) the loss of personal data; (b) the unauthorized or unlawful processing, disclosure, access, alteration, corruption, transfer, sale, rental, destruction, or use of personal data; and (c) relevant definitions provided by applicable law. Compliance by Receiving Party and its subcontractors and agents with this Section is a material obligation of this Agreement.16. SUPPLIER CODE OF CONDUCT  16.1 Seller shall comply with Buyer's Code of Business Conduct for Suppliers (\"Supplier Code of Conduct). In the event there is a conflict between Suppliers Code of Conduct and the terms and conditions of this Agreement, the terms and conditions of this Agreement shall govern. Buyer may modify the Supplier Code of Conduct at any time and provide written notice to Seller of such modifications. Notwithstanding, Seller may, as an alternative and subject to Buyer's prior review and approval, comply with Seller's own code of conduct if it is deemed to be substantially similar to Buyer's.17. SECURITY PROGRAMS 47.1 Seller shall supply documentation demonstrating that it is properly certified under, and is in compliance with, one or more of the following supply chain security programs, as applicable: the Canadian Partners In Protection (PIP), the U.S. Customs-Trade Partnership Against Terrorism (C-TPAT) or an equivalent World Customs Organization (\"WCO\") accredited security program administered by a foreign customs agency. Alternatively, Seller may demonstrate that it is meeting the applicable supply chain security criteria by completing a risk assessment provided by Buyer. Should Seller fail to provide evidence of such certification and compliance, or fail to achieve a satisfactory rating on Buyer's risk assessment, then Buyer may terminate this Agreement, upon sixty (60) day advanced written notice, during which Seller may cure such failure. 18. CAPTIONS18.1 Captions used in this Agreement are for convenience only and shall not affect the meaning of construction of any of the provisions of this Agreement. 19. SEPARABILITY OF PROVISIONS 19.1 The invalidity, illegality or unenforceability of any provision(s) of the Agreement shall in no way effect or impair the validity, legality, and enforceability of the remaining provisions hereof. 20. ENTIRETY OF AGREEMENT/AMENDMENTS 20.1 Seller and Buyer agree that this document sets forth their entire agreement and there are no promised or understandings other than those stated herein. No amendment, modification or supplement to this Agreement shall be binding unless it is in writing, signed by both Parties authorized representatives. 21. WAIVERS 21.1 No waiver, whether expressed or implied, by either Party or any breach of any of the covenants or conditions contained in the Agreement shail be construed as a waiver of any succeeding breach of the same or of any other covenant or condition. 22. ASSIGNMENT 22.1 Neither Party shall have the right to assign this Agreement without the prior written consent of the other Party, whose consent shall not be unreasonably withheld, provided however that either Party may assign to an affiliate. For purposes of this Agreement, an Affiliate is any company, corporation, general or limited partnership, limited liability company, joint venture, organization, association, or other enterprise or entity in which a Party directly, or indirectly through one or more intermediaries, has an ownership interest (as a result of ownership of stock or other voting securities, contractual relationship, or otherwise).23. RESPONSIBLE CARE  23.1 Seller and Buyer are committed to support and improve the chemical industry's responsible management of chemicals and to be guided by the principles of the Responsible Care initiatives of the Chemistry Industry Association of Canada and the American Chemistry Council. Seller and Buyer agree to manage their respective businesses consistent with these principles or a similarly comprehensive health, safety and environmental program. Consistent with such Responsible Care programs, Seller and Buyer may request bi-annual visits to the Buyer's Plants and Seller's Plant respectively, to review the acid handling practices and systems. 23.2 Seller and Buyer will provide one another the current Material Safety Data Sheets or Global Harmonization Standards (GHS) safety data sheets covering the Product(s) in Exhibit A and B and will ensure updates are received promptly. 24. APPLICABLE LAW 24.1 This Agreement shall be governed by the laws of the State of Delaware. 25. NOTICE  25.1 Notice under this contract shall be sent to: Buyer at: The Dow Chemical Company 715 E. Main St (East End Offices) Midland, Mi 48674Attn: Strategic Sourcing, RM Purchasing Seller at: Chemtrade Refinery Solutions GP ULC c/o 155 Gordon Baker Road"""
question = {"1.How will Consumer Price Index (CPI) be reviewed under the Consumer Price Index Clause?":"Answer", 
            "2.When will CPI be reviewed under the Consumer Price Index Clause?":"Answer",
            "3.How are adjustments made for CPI under the Consumer Price Index Clause?":"Answer",
            "4.Is there any inflation rate or formula or increase/decraese rate of Consumer Price Index mentioned under the Consumer Price Index Clause?":"Answer",
            "5.What is the cost of living adjustment (COLA) under the Cost of Living adjustment Clause?":"Answer",
            "6.What are the contract terms based on changes in the cost of living under the Cost of Living adjustment Clause?":"Answer",
            "7.What is the payment frequency? Return the response in one word only if mentioned explicitly.":"Answer",
            "8.What is payment trigger event under the Payment Trigger clause ?":"Answer",
            "9.Which party will make the payment to other party under the Payment Frequency clause ?":"Answer",
            "10.How Consumer Price Index (CPI) is contributing to the Cost of Living Adjustment (COLA) under the Cost of Living adjustment Clause?":"Answer",
            "11.What is the change in contract term based on CPI under the Cost of Living adjustment?":"Answer"
            }  
res = eval(llm_chain.run({"question":question, "text":text}))
print(res)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\SWAPNI~1.JOS\AppData\Local\Temp/ipykernel_21332/3239086232.py in <module>
#       6 import gc
#       7 import os
# ----> 8 from langchain.chat_models import AzureChatOpenAI
#       9 from langchain.prompts import PromptTemplate
#      10 from langchain.chains import LLMChain
#
# ModuleNotFoundError: No module named 'langchain'

# %%
pip install langchain
# Out:
# ...
#      ------------------------------------ 809.1/809.1 kB 262.2 kB/s eta 0:00:00
# ...
#   Using cached pydantic-2.5.2-py3-none-any.whl (381 kB)
# ...
#      -------------------------------------- 46.0/46.0 kB 458.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 436.5 kB/s eta 0:00:00
# ...
#      ------------------------------------ 189.1/189.1 kB 674.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 49.4/49.4 kB 1.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 53.0/53.0 kB 689.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 83.9/83.9 kB 1.6 MB/s eta 0:00:00
# ...
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# ...
#   Using cached pydantic_core-2.14.5-cp39-none-win_amd64.whl (1.9 MB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install --upgrade pip
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pip in c:\users\swapnil.joshi\appdata\roaming\python\python39\site-packages (22.3.1)
# ...
#      ---------------------------------------- 2.1/2.1 MB 393.6 kB/s eta 0:00:00
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -9ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -8ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -7ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -6ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -5ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4ckaging (c:\programdata\anaconda3\lib\site-packages)
# ...
